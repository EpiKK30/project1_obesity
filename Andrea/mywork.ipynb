# %%
#dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import pearsonr


# Read and load the obesity dataset
obesity_df = pd.read_csv("../project1_obesity/ObesityDataSet.csv")
obesity_df.head()
# Out:
#    Gender   Age  Height(m)  Weight(kg) family_history_with_overweight  \
# 0  Female  21.0       1.62        64.0                            yes
# 1  Female  21.0       1.52        56.0                            yes
# 2    Male  23.0       1.80        77.0                            yes
# 3    Male  27.0       1.80        87.0                             no
# 4    Male  22.0       1.78        89.8                             no
#
#   FAVC(Frequent Consumption of  High Caloric Food)  \
# 0                                               no
# 1                                               no
# 2                                               no
# 3                                               no
# 4                                               no
#
#    FCVC(Frequency of consumption of Vegetables)  NCP( Number of Main Meals)  \
# 0                                           2.0                         3.0
# 1                                           3.0                         3.0
# 2                                           2.0                         3.0
# 3                                           3.0                         3.0
# 4                                           2.0                         1.0
#
#   CAEC( Consumption of Food Between Meals) SMOKE  CH2O(Consumption of Water)  \
# 0                                Sometimes    no                         2.0
# 1                                Sometimes   yes                         3.0
# 2                                Sometimes    no                         2.0
# 3                                Sometimes    no                         2.0
# 4                                Sometimes    no                         2.0
#
#   SCC(Caloric  Consumption Monitoring)  FAF( Physical Activity Frequency)  \
# 0                                   no                                0.0
# 1                                  yes                                3.0
# 2                                   no                                2.0
# 3                                   no                                2.0
# 4                                   no                                0.0
#
#    TUE(Time Using Technology Devices) CALC( Consumption of Alcohol)  \
# 0                                 1.0                            no
# 1                                 0.0                     Sometimes
# 2                                 1.0                    Frequently
# 3                                 0.0                    Frequently
# 4                                 0.0                     Sometimes
#
#   MTRANS(Transportation Use) Nobeyesdad(Classification of Weight)
# 0      Public_Transportation                        Normal_Weight
# 1      Public_Transportation                        Normal_Weight
# 2      Public_Transportation                        Normal_Weight
# 3                    Walking                   Overweight_Level_I
# 4      Public_Transportation                  Overweight_Level_II

# %% [markdown]
# ### DATA CLEANING AND EXPLORATION

# %%
# Display basic information about the obesity dataset
#finding missing values
obesity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Gender                                            2111 non-null   object
#  1   Age                                               2111 non-null   float64
#  2   Height(m)                                         2111 non-null   float64
#  3   Weight(kg)                                        2111 non-null   float64
#  4   family_history_with_overweight                    2111 non-null   object
#  5   FAVC(Frequent Consumption of  High Caloric Food)  2111 non-null   object
#  6   FCVC(Frequency of consumption of Vegetables)      2111 non-null   float64
#  7   NCP( Number of Main Meals)                        2111 non-null   float64
#  8   CAEC( Consumption of Food Between Meals)          2111 non-null   object
#  9   SMOKE                                             2111 non-null   object
#  10  CH2O(Consumption of Water)                        2111 non-null   float64
#  11  SCC(Caloric  Consumption Monitoring)              2111 non-null   object
#  12  FAF( Physical Activity Frequency)                 2111 non-null   float64
#  13  TUE(Time Using Technology Devices)                2111 non-null   float64
#  14  CALC( Consumption of Alcohol)                     2111 non-null   object
#  15  MTRANS(Transportation Use)                        2111 non-null   object
#  16  Nobeyesdad(Classification of Weight)              2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
# Generate descriptive statistics
obesity_df.describe().round(2)
# Out:
#            Age  Height(m)  Weight(kg)  \
# count  2111.00    2111.00     2111.00
# mean     24.31       1.70       86.59
# std       6.35       0.09       26.19
# min      14.00       1.45       39.00
# 25%      19.95       1.63       65.47
# 50%      22.78       1.70       83.00
# 75%      26.00       1.77      107.43
# max      61.00       1.98      173.00
#
#        FCVC(Frequency of consumption of Vegetables)  \
# count                                       2111.00
# mean                                           2.42
# std                                            0.53
# min                                            1.00
# 25%                                            2.00
# 50%                                            2.39
# 75%                                            3.00
# max                                            3.00
#
#        NCP( Number of Main Meals)  CH2O(Consumption of Water)  \
# count                     2111.00                     2111.00
# mean                         2.69                        2.01
# std                          0.78                        0.61
# min                          1.00                        1.00
# 25%                          2.66                        1.58
# 50%                          3.00                        2.00
# 75%                          3.00                        2.48
# max                          4.00                        3.00
#
#        FAF( Physical Activity Frequency)  TUE(Time Using Technology Devices)
# count                            2111.00                             2111.00
# mean                                1.01                                0.66
# std                                 0.85                                0.61
# min                                 0.00                                0.00
# 25%                                 0.12                                0.00
# 50%                                 1.00                                0.63
# 75%                                 1.67                                1.00
# max                                 3.00                                2.00

# %%
#determining categorical data
categorical = obesity_df.dtypes[obesity_df.dtypes == "object"].index
print(categorical)

obesity_df[categorical].describe()
# Out:
# Index(['Gender', 'family_history_with_overweight',
#        'FAVC(Frequent Consumption of  High Caloric Food)',
#        'CAEC( Consumption of Food Between Meals)', 'SMOKE',
#        'SCC(Caloric  Consumption Monitoring)', 'CALC( Consumption of Alcohol)',
#        'MTRANS(Transportation Use)', 'Nobeyesdad(Classification of Weight)'],
#       dtype='object')
#        Gender family_history_with_overweight  \
# count    2111                           2111
# unique      2                              2
# top      Male                            yes
# freq     1068                           1726
#
#        FAVC(Frequent Consumption of  High Caloric Food)  \
# count                                              2111
# unique                                                2
# top                                                 yes
# freq                                               1866
#
#        CAEC( Consumption of Food Between Meals) SMOKE  \
# count                                      2111  2111
# unique                                        4     2
# top                                   Sometimes    no
# freq                                       1765  2067
#
#        SCC(Caloric  Consumption Monitoring) CALC( Consumption of Alcohol)  \
# count                                  2111                          2111
# unique                                    2                             4
# top                                      no                     Sometimes
# freq                                   2015                          1401
#
#        MTRANS(Transportation Use) Nobeyesdad(Classification of Weight)
# count                        2111                                 2111
# unique                          5                                    7
# top         Public_Transportation                       Obesity_Type_I
# freq                         1580                                  351

# %%
#renaming columns for easy use
obesity_df= obesity_df.rename(columns={"family_history_with_overweight": "Fhx of Overweight",
                                      "FAVC(Frequent Consumption of  High Caloric Food)":"Freq High Calorie Cons",
                                      "CAEC( Consumption of Food Between Meals)":"Eating inbetween meals",
                                      "SCC(Caloric  Consumption Monitoring)":"Calorie Consumption Monitoring",
                                      "CALC( Consumption of Alcohol)":"Alcohol consumption",
                                      "MTRANS(Transportation Use)":"Transportation used",
                                      "Nobeyesdad(Classification of Weight)":"Weight group",
                                      "FCVC(Frequency of consumption of Vegetables)":"Freq vegetable cons",
                                      "NCP( Number of Main Meals)":"Number of Main Meals",
                                      "SMOKE":"Hx of smoking",
                                      "CH2O(Consumption of Water)":"Water consumption",
                                     "FAF( Physical Activity Frequency)":"Freq of Physical Activity",
                                      "TUE(Time Using Technology Devices)":"Time spent on Tech devices"})
obesity_df.head()
# Out:
#    Gender   Age  Height(m)  Weight(kg) Fhx of Overweight  \
# 0  Female  21.0       1.62        64.0               yes
# 1  Female  21.0       1.52        56.0               yes
# 2    Male  23.0       1.80        77.0               yes
# 3    Male  27.0       1.80        87.0                no
# 4    Male  22.0       1.78        89.8                no
#
#   Freq High Calorie Cons  Freq vegetable cons  Number of Main Meals  \
# 0                     no                  2.0                   3.0
# 1                     no                  3.0                   3.0
# 2                     no                  2.0                   3.0
# 3                     no                  3.0                   3.0
# 4                     no                  2.0                   1.0
#
#   Eating inbetween meals Hx of smoking  Water consumption  \
# 0              Sometimes            no                2.0
# 1              Sometimes           yes                3.0
# 2              Sometimes            no                2.0
# 3              Sometimes            no                2.0
# 4              Sometimes            no                2.0
#
#   Calorie Consumption Monitoring  Freq of Physical Activity  \
# 0                             no                        0.0
# 1                            yes                        3.0
# 2                             no                        2.0
# 3                             no                        2.0
# 4                             no                        0.0
#
#    Time spent on Tech devices Alcohol consumption    Transportation used  \
# 0                         1.0                  no  Public_Transportation
# 1                         0.0           Sometimes  Public_Transportation
# 2                         1.0          Frequently  Public_Transportation
# 3                         0.0          Frequently                Walking
# 4                         0.0           Sometimes  Public_Transportation
#
#           Weight group
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
#calclating BMI for each datapoint and creating a new column for that information
BMI= obesity_df["Weight(kg)"]/(obesity_df["Height(m)"]**2)
obesity_df["BMI"] = round(BMI,1)  
obesity_df.head()
# Out:
#    Gender   Age  Height(m)  Weight(kg) Fhx of Overweight  \
# 0  Female  21.0       1.62        64.0               yes
# 1  Female  21.0       1.52        56.0               yes
# 2    Male  23.0       1.80        77.0               yes
# 3    Male  27.0       1.80        87.0                no
# 4    Male  22.0       1.78        89.8                no
#
#   Freq High Calorie Cons  Freq vegetable cons  Number of Main Meals  \
# 0                     no                  2.0                   3.0
# 1                     no                  3.0                   3.0
# 2                     no                  2.0                   3.0
# 3                     no                  3.0                   3.0
# 4                     no                  2.0                   1.0
#
#   Eating inbetween meals Hx of smoking  Water consumption  \
# 0              Sometimes            no                2.0
# 1              Sometimes           yes                3.0
# 2              Sometimes            no                2.0
# 3              Sometimes            no                2.0
# 4              Sometimes            no                2.0
#
#   Calorie Consumption Monitoring  Freq of Physical Activity  \
# 0                             no                        0.0
# 1                            yes                        3.0
# 2                             no                        2.0
# 3                             no                        2.0
# 4                             no                        0.0
#
#    Time spent on Tech devices Alcohol consumption    Transportation used  \
# 0                         1.0                  no  Public_Transportation
# 1                         0.0           Sometimes  Public_Transportation
# 2                         1.0          Frequently  Public_Transportation
# 3                         0.0          Frequently                Walking
# 4                         0.0           Sometimes  Public_Transportation
#
#           Weight group   BMI
# 0        Normal_Weight  24.4
# 1        Normal_Weight  24.2
# 2        Normal_Weight  23.8
# 3   Overweight_Level_I  26.9
# 4  Overweight_Level_II  28.3

# %%
#Classifying weight
for i in obesity_df["BMI"]:
    if i < 18.5:
        obesity_df.loc[obesity_df["BMI"]== i,"Weight classification"] = "Underweight"
    elif i <= 24.9:
        obesity_df.loc[obesity_df["BMI"]== i,"Weight classification"] = "Normal"
    elif i <= 29.9:
        obesity_df.loc[obesity_df["BMI"]== i,"Weight classification"] = "Overweight"
    else:
        obesity_df.loc[obesity_df["BMI"]== i,"Weight classification"] = "Obese"

obesity_df
# Out:
#       Gender    Age  Height(m)  Weight(kg) Fhx of Overweight  \
# 0     Female  21.00       1.62       64.00               yes
# 1     Female  21.00       1.52       56.00               yes
# 2       Male  23.00       1.80       77.00               yes
# 3       Male  27.00       1.80       87.00                no
# 4       Male  22.00       1.78       89.80                no
# ...      ...    ...        ...         ...               ...
# 2106  Female  20.98       1.71      131.41               yes
# 2107  Female  21.98       1.75      133.74               yes
# 2108  Female  22.52       1.75      133.69               yes
# 2109  Female  24.36       1.74      133.35               yes
# 2110  Female  23.66       1.74      133.47               yes
#
#      Freq High Calorie Cons  Freq vegetable cons  Number of Main Meals  \
# 0                        no                  2.0                   3.0
# 1                        no                  3.0                   3.0
# 2                        no                  2.0                   3.0
# 3                        no                  3.0                   3.0
# 4                        no                  2.0                   1.0
# ...                     ...                  ...                   ...
# 2106                    yes                  3.0                   3.0
# 2107                    yes                  3.0                   3.0
# 2108                    yes                  3.0                   3.0
# 2109                    yes                  3.0                   3.0
# 2110                    yes                  3.0                   3.0
#
#      Eating inbetween meals Hx of smoking  Water consumption  \
# 0                 Sometimes            no               2.00
# 1                 Sometimes           yes               3.00
# 2                 Sometimes            no               2.00
# 3                 Sometimes            no               2.00
# 4                 Sometimes            no               2.00
# ...                     ...           ...                ...
# 2106              Sometimes            no               1.73
# 2107              Sometimes            no               2.01
# 2108              Sometimes            no               2.05
# 2109              Sometimes            no               2.85
# 2110              Sometimes            no               2.86
#
#      Calorie Consumption Monitoring  Freq of Physical Activity  \
# 0                                no                       0.00
# 1                               yes                       3.00
# 2                                no                       2.00
# 3                                no                       2.00
# 4                                no                       0.00
# ...                             ...                        ...
# 2106                             no                       1.68
# 2107                             no                       1.34
# 2108                             no                       1.41
# 2109                             no                       1.14
# 2110                             no                       1.03
#
#       Time spent on Tech devices Alcohol consumption    Transportation used  \
# 0                           1.00                  no  Public_Transportation
# 1                           0.00           Sometimes  Public_Transportation
# 2                           1.00          Frequently  Public_Transportation
# 3                           0.00          Frequently                Walking
# 4                           0.00           Sometimes  Public_Transportation
# ...                          ...                 ...                    ...
# 2106                        0.91           Sometimes  Public_Transportation
# 2107                        0.60           Sometimes  Public_Transportation
# 2108                        0.65           Sometimes  Public_Transportation
# 2109                        0.59           Sometimes  Public_Transportation
# 2110                        0.71           Sometimes  Public_Transportation
#
#        BMI Weight classification
# 0     24.4                Normal
# 1     24.2                Normal
# 2     23.8                Normal
# 3     26.9            Overweight
# 4     28.3            Overweight
# ...    ...                   ...
# 2106  44.9                 Obese
# 2107  43.7                 Obese
# 2108  43.7                 Obese
# 2109  44.0                 Obese
# 2110  44.1                 Obese
#
# [2111 rows x 18 columns]

# %%
obesity_df.to_csv("output/obesity.csv", index_label="ID")

# %%
labels=["Male","Female"]
plt.pie(obesity_df["Gender"].value_counts(), autopct = "%1.1f%%", labels=labels, shadow = True)
plt.title("Gender Distribution")
plt.show()

# %%
labels=["Underweight","Normal","Overweight","Obese"]
explode = [0,0,0,0.2]
plt.pie(obesity_df["Weight classification"].value_counts(), autopct = "%1.1f%%",shadow = True, labels=labels, explode = explode)
plt.title("Weight Classification")
plt.show()

# %%
# assessing the extent of family hx of overweight, since family history is the only non modifiable factor being analysed.
x= np.arange(2)
xticks= ("yes", "no")
plt.bar(x,obesity_df["Fhx of Overweight"].value_counts(), color = "g", alpha = 0.7)
plt.xticks(x, xticks)
plt.xlabel("Response")
plt.ylabel("Number of Repondents")
plt.title("Number of respondents with and without family hx of Overweight")
plt.show()

# %%
#
